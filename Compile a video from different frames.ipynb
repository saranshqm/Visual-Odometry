# %%
#best one


import cv2
import numpy as np
import os
 
from os.path import isfile, join
 
def convert_frames_to_video(pathIn,pathOut,fps):
    frame_array = []
    files = [f for f in os.listdir(pathIn) if isfile(join(pathIn, f))]
 
    #for sorting the file names properly
    files.sort(key = lambda x: int(x[4:-4]))
 
    for i in range(len(files)):
        filename=pathIn + files[i]
        #reading each files
        img = cv2.imread(filename)
        height, width, layers = img.shape
        size = (width,height)
#         size = (512,512)
        print(filename)
        #inserting the frames into an image array
        frame_array.append(img)
 
    out = cv2.VideoWriter(pathOut,cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
 
    for i in range(len(frame_array)):
        # writing to a image array
        out.write(frame_array[i])
    out.release()
 
def main():
    pathIn= 'D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/'
    pathOut = 'D:/Swayatt Robots/work/work done/dataSets/new data/saransh/video.mp4'
    fps = 20
    convert_frames_to_video(pathIn, pathOut, fps)
 
if __name__=="__main__":
    main()
# Out:
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_0.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_5.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_10.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_15.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_20.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_25.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_30.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_35.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_40.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_45.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_50.jpg
# D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh/img_55.jpg
# ...

# %% [markdown]
# best code to auto annotate images

# %%
import cv2
import numpy as np

from os.path import isfile, join
import os

image_folder='.'

os.chdir("D:/Swayatt Robots/work/work done/dataSets/new data/saransh/saransh") 

output_directory = r'D:/Swayatt Robots/work/work done/dataSets/new data/saransh'

files = [f for f in os.listdir(image_folder) if isfile(join(image_folder, f))]

#for sorting the file names properly
files.sort(key = lambda x: int(x[4:-4]))


key = 0
for image in files:
    img = cv2.pyrDown(cv2.imread(image, cv2.IMREAD_UNCHANGED))

    # threshold image
    ret, threshed_img = cv2.threshold(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY),
                    127, 255, cv2.THRESH_BINARY)
    contours, hier = cv2.findContours(threshed_img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    for c in contours[300:630]:
        # get the bounding rect
        x, y, w, h = cv2.boundingRect(c)
        # draw a green rectangle to visualize the bounding rect
        img = cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
        # Filename 
        
    print(len(contours))
    cv2.drawContours(img, contours, -1, (255, 255, 0), 1)
    
    filename = str(key)+'.jpg'
    # Using cv2.imwrite() method 
    # Saving the image 
    os.listdir(output_directory)
    cv2.imwrite(filename, img)
    key+=1
    
    

# cv2.imshow("contours", img)

# cv2.imshow("contours", img)

# while True:
#     key = cv2.waitKey(1)
#     if key == 27: #ESC key to break
#         break

# cv2.destroyAllWindows()
# Out:
# 1151
# 1146
# 1168
# 1180
# 1181
# 1176
# 1188
# 1171
# 1151
# 1145
# 1156
# 1151
# 1198
# 1179
# 1192
# 1204
# 1173
# 1156
# 1188
# 1156
# 1152
# 1185
# 1190
# 1200
# 1182
# 1186
# 1168
# 1181
# 1168
# 1174
# 1148
# 1176
# 1134
# 1175
# 1158
# 1149
# 1150
# 1181
# 1163
# 1162
# 1136
# 1139
# 1166
# 1153
# 1181
# 1169
# 1159
# 1157
# 1162
# 1188
# 1160
# 1160
# 1164
# 1153
# 1127
# 1116
# 1115
# 1136
# 1112
# 1111
# 1054
# 1063
# 1089
# 1049
# 1033
# 1044
# 1076
# 1034
# 1075
# 1102
# 1151
# 1179
# 1227
# 1240
# 1161
# 1102
# 1065
# 1089
# 1019
# 960
# 935
# 893
# 828
# 840
# 783
# 742
# 747
# 724
# 702
# 693
# 723
# 700
# 710
# 705
# 703
# 703
# 717
# 707
# 711
# 744
# 742
# 691
# 648
# 609
# 650
# 550
# 504
# 542
# 540
# 545
# 515
# 515
# 549
# 557
# 557
# 550
# 547
# 547
# 501
# 486
# 484
# 460
# 450
# 489
# 483
# 513
# 499
# 541
# 584
# 575
# 581
# 575
# 591
# 594
# 600
# 613
# 663
# 717
# 682
# 742
# 701
# 816
# 794
# 859
# 936
# 1052
# 1096
# 993
# 908
# 900
# 816
# 813
# 777
# ...

# %%
key = 1
filename = str(key)+'.jpg'
filename
# Out:
# '1.jpg'
